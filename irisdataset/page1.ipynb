# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
iris = pd.read_csv("irisdataset.csv")
iris.shape
iris.columns
iris.value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 4.9           3.1          1.5           0.1          setosa        3
# 5.8           2.7          5.1           1.9          virginica     2
#               4.0          1.2           0.2          setosa        1
# 5.9           3.0          4.2           1.5          versicolor    1
# 6.2           3.4          5.4           2.3          virginica     1
#                                                                    ..
# 5.5           2.3          4.0           1.3          versicolor    1
#               2.4          3.7           1.0          versicolor    1
#                            3.8           1.1          versicolor    1
#               2.5          4.0           1.3          versicolor    1
# 7.9           3.8          6.4           2.0          virginica     1
# Length: 147, dtype: int64

# %%
iris.plot(kind="scatter",grid=True,x="sepal_length",y="sepal_width")
iris.plot(kind="scatter",x="petal_length",y="petal_width")
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris,hue="species",height=5).map(plt.scatter,"sepal_length","sepal_width").add_legend()
# Linearly seperated

# %% [markdown]
# ### Obeservations:
#
# 1. Using sepal_length and sepal_width we can distinguish setosa flowers from others.
# 2. Seperating versicolor and virginica is hard, as there is much overlapping in them.

# %% [markdown]
# ## Pair Scatter Plot
#
# 1. since we have (petal_width, sepal_width, petal_length, petal_width) we can create 4C2 axes i.e. 6.

# %%
sns.pairplot(iris,hue="species",height=3)
# plotting all possible graphs
